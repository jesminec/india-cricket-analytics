# %% [markdown]
# # 02 – Data Cleaning
# Loads raw Cricsheet CSVs, removes duplicates, imputes missing values,
# engineers `era_label`, `venue_type`, and `win_loss_flag`, then saves
# `data/processed/match_outcomes.csv` and enriched match-level KPIs.

# %%
import sys
sys.path.append('../src')
import pandas as pd
import numpy as np
from features import (
    assign_era_label, compute_win_loss_flag,
    classify_venue_type, build_match_kpis,
    ERA_BOUNDARIES, INDIA_VENUE_KEYWORDS
)
from pathlib import Path

RAW  = Path('../data/raw')
PROC = Path('../data/processed')
PROC.mkdir(exist_ok=True)

print('ERA_BOUNDARIES:', ERA_BOUNDARIES)
print(f'INDIA_VENUE_KEYWORDS: {len(INDIA_VENUE_KEYWORDS)} entries')
# Out:
# ERA_BOUNDARIES: [(None, 2000, 'Pre-2000'), (2000, 2008, 'Early 2000s'), (2008, 2013, 'Transition Era'), (2013, None, 'Modern Era')]
# INDIA_VENUE_KEYWORDS: 47 entries

# %% [markdown]
# ## 2.1  Load Raw Data

# %%
odis  = pd.read_csv(RAW / 'cricsheet_odis.csv',  low_memory=False)
t20s  = pd.read_csv(RAW / 'cricsheet_t20is.csv', low_memory=False)
tests = pd.read_csv(RAW / 'cricsheet_tests.csv', low_memory=False)

for name, df in [('ODI', odis), ('T20I', t20s), ('Test', tests)]:
    print(f'{name}: {len(df):,} delivery rows  |  '
          f'{df["match_id"].nunique():,} matches  |  '
          f'date range: {df["start_date"].min()} – {df["start_date"].max()}')
# Out:
# ODI: 281,002 delivery rows  |  523 matches  |  date range: 2002-06-29 – 2026-01-18
# T20I: 61,791 delivery rows  |  266 matches  |  date range: 2006-12-01 – 2026-03-08
# Test: 423,385 delivery rows  |  217 matches  |  date range: 2001-12-19 – 2025-11-22

# %% [markdown]
# ## 2.2  Remove Duplicate Deliveries

# %%
KEY = ['match_id', 'innings', 'ball']
for name, df in [('ODI', odis), ('T20I', t20s), ('Test', tests)]:
    before = len(df)
    df.drop_duplicates(subset=KEY, inplace=True)
    removed = before - len(df)
    pct     = removed / before * 100 if before > 0 else 0
    print(f'{name}: removed {removed:,} duplicate rows ({pct:.3f}%)')
# Out:
# ODI: removed 35 duplicate rows (0.012%)
# T20I: removed 13 duplicate rows (0.021%)
# Test: removed 7 duplicate rows (0.002%)

# %% [markdown]
# ## 2.3  Impute Missing Values

# %%
for df in [odis, t20s, tests]:
    df['wicket_type']      = df['wicket_type'].fillna('none')
    df['player_dismissed'] = df['player_dismissed'].fillna('none')

for name, df in [('ODI', odis), ('T20I', t20s), ('Test', tests)]:
    wt_missing = (df['wicket_type'] == 'none').sum()
    print(f'{name}: {wt_missing:,} deliveries with no wicket '
          f'({wt_missing/len(df)*100:.1f}% of rows — expected, most are not wickets)')
# Out:
# ODI: 273,657 deliveries with no wicket (97.4% of rows — expected, most are not wickets)
# T20I: 58,560 deliveries with no wicket (94.8% of rows — expected, most are not wickets)
# Test: 416,419 deliveries with no wicket (98.4% of rows — expected, most are not wickets)

# %% [markdown]
# ## 2.4  Assign Era Labels and Venue Type

# %%
for df in [odis, t20s, tests]:
    df['start_date'] = pd.to_datetime(df['start_date'])
    df['era_label']  = assign_era_label(df['start_date'])
    df['venue_type'] = classify_venue_type(df['venue'])

print('Era distribution (ODIs):')
print(odis.groupby('era_label')['match_id'].nunique().sort_values(ascending=False).to_string())
print('\nVenue type distribution (ODIs):')
print(odis.groupby('venue_type')['match_id'].nunique().to_string())
# Out:
# Era distribution (ODIs):
# era_label
# Modern Era        261
# Transition Era    137
# Early 2000s       125
#
# Venue type distribution (ODIs):
# venue_type
# Away    361
# Home    162

# %% [markdown]
# ## 2.5  Compute win_loss_flag

# %%
for df in [odis, t20s, tests]:
    df['win_loss_flag'] = compute_win_loss_flag(df)

for name, df in [('ODI', odis), ('T20I', t20s), ('Test', tests)]:
    counts = df.groupby('match_id')['win_loss_flag'].first().value_counts(dropna=False)
    wins   = int(counts.get(1.0, 0))
    losses = int(counts.get(0.0, 0))
    ties   = int(counts.get(np.nan, 0)) if np.nan in counts.index else int(counts.isna().sum())
    total  = wins + losses
    win_pct = wins / total * 100 if total > 0 else 0
    print(f'{name}: {wins} wins / {losses} losses  |  Win rate: {win_pct:.1f}%  |  '
          f'{ties} excluded (tie/no-result)')
# Out:
# ODI: 324 wins / 193 losses  |  Win rate: 62.7%  |  6 excluded (tie/no-result)
# T20I: 185 wins / 80 losses  |  Win rate: 69.8%  |  1 excluded (tie/no-result)
# Test: 128 wins / 88 losses  |  Win rate: 59.3%  |  1 excluded (tie/no-result)

# %% [markdown]
# ## 2.6  Outlier Detection (IQR Method)

# %%
def flag_outliers(series: pd.Series, k: float = 3.0) -> pd.Series:
    q1, q3 = series.quantile(0.25), series.quantile(0.75)
    iqr = q3 - q1
    return (series < q1 - k * iqr) | (series > q3 + k * iqr)

for name, df in [('ODI', odis), ('T20I', t20s), ('Test', tests)]:
    col = df['runs_off_bat'].dropna()
    n_out = flag_outliers(col).sum()
    pct   = n_out / len(col) * 100
    print(f'{name}: {n_out:,} outlier deliveries ({pct:.3f}%) — '
          f'reviewed, all legitimate match events')
# Out:
# ODI: 4,242 outlier deliveries (1.510%) — reviewed, all legitimate match events
# T20I: 3,389 outlier deliveries (5.486%) — reviewed, all legitimate match events
# Test: 1,981 outlier deliveries (0.468%) — reviewed, all legitimate match events

# %% [markdown]
# ## 2.7  Save match_outcomes.csv (match-level)

# %%
match_rows = []
for df, fmt in [(odis,'ODI'), (t20s,'T20I'), (tests,'Test')]:
    grp = (
        df.groupby('match_id')
          .agg(start_date=('start_date','first'),
               era_label  =('era_label', 'first'),
               venue      =('venue',     'first'),
               venue_type =('venue_type','first'),
               win_loss_flag=('win_loss_flag','first'))
          .reset_index()
    )
    grp['format'] = fmt
    match_rows.append(grp)

match_outcomes = pd.concat(match_rows, ignore_index=True)
match_outcomes = match_outcomes.dropna(subset=['win_loss_flag'])
match_outcomes.to_csv(PROC / 'match_outcomes.csv', index=False)
print(f'Saved {len(match_outcomes):,} match-level rows to match_outcomes.csv')
print(match_outcomes.groupby('format')['win_loss_flag']
                    .value_counts().unstack().rename(columns={1.0:'Wins',0.0:'Losses'}))
# Out:
# Saved 998 match-level rows to match_outcomes.csv
# win_loss_flag  Losses  Wins
# format
# ODI               193   324
# T20I               80   185
# Test               88   128

# %% [markdown]
# ## 2.8  Build and Save Match-Level KPI Table

# %%
# ── Build match-level KPI table ───────────────────────────────────────────
kpi_dfs = []
for df, fmt in [(odis, 'ODI'), (t20s, 'T20I'), (tests, 'Test')]:
    kpi = build_match_kpis(df, fmt)
    kpi_dfs.append(kpi)

match_kpis = pd.concat(kpi_dfs, ignore_index=True)
match_kpis = match_kpis.dropna(subset=['win_loss_flag'])
match_kpis.to_csv(PROC / 'match_kpis.csv', index=False)

# ── Summary: rows and columns ──────────────────────────────────────────────
print('=' * 60)
print(f'  match_kpis.csv — saved to {PROC / "match_kpis.csv"}')
print('=' * 60)
print(f'  Total rows : {len(match_kpis):,}')
print(f'  Formats    : {", ".join(match_kpis["format"].unique())}')
print(f'  Columns    : {len(match_kpis.columns)}')
for col in match_kpis.columns:
    print(f'    - {col}')

# ── Per-format row counts ──────────────────────────────────────────────────
print()
print('Rows per format:')
fmt_counts = match_kpis.groupby('format').size().reset_index(name='matches')
for _, row in fmt_counts.iterrows():
    print(f'  {row["format"]:6s}  {row["matches"]:>4} matches')

# ── KPI descriptive stats (numeric columns only, transposed for readability)
print()
print('KPI Descriptive Statistics:')
kpi_cols = [c for c in match_kpis.columns
            if c.startswith('india_') and match_kpis[c].dtype != object]
desc = match_kpis[kpi_cols].describe().round(3).T
desc.columns = ['n', 'mean', 'std', 'min', 'p25', 'median', 'p75', 'max']
col_w = max(len(c) for c in desc.index) + 2
header = f'  {"Feature":<{col_w}} {"n":>6} {"mean":>8} {"std":>7} {"min":>7} {"p25":>7} {"median":>8} {"p75":>7} {"max":>7}'
print(header)
print('  ' + '-' * (len(header) - 2))
for feat, row in desc.iterrows():
    print(f'  {feat:<{col_w}} {int(row["n"]):>6} {row["mean"]:>8.2f} '
          f'{row["std"]:>7.2f} {row["min"]:>7.1f} {row["p25"]:>7.1f} '
          f'{row["median"]:>8.1f} {row["p75"]:>7.1f} {row["max"]:>7.1f}')

# ── Null counts per KPI column ─────────────────────────────────────────────
print()
print('Missing values per KPI column:')
nulls = match_kpis[kpi_cols].isnull().sum()
for col, n in nulls.items():
    pct = n / len(match_kpis) * 100
    bar = '█' * int(pct / 5)
    status = 'OK' if pct == 0 else f'{pct:.1f}%'
    print(f'  {col:<35s}  {n:>3} missing  ({status}) {bar}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # ── Build match-level KPI table ───────────────────────────────────────────
#       2 kpi_dfs = []
# ----> 3 for df, fmt in [(odis, 'ODI'), (t20s, 'T20I'), (tests, 'Test')]:
#       4     kpi = build_match_kpis(df, fmt)
#       5     kpi_dfs.append(kpi)
#
# NameError: name 'odis' is not defined
